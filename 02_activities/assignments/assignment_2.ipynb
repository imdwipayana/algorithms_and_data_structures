# %% [markdown]
# # Practice Interview
#
# ## Objective
#
# _*The partner assignment aims to provide participants with the opportunity to practice coding in an interview context. You will analyze your partner's Assignment 1. Moreover, code reviews are common practice in a software development team. This assignment should give you a taste of the code review process.*_
#
# ## Group Size
#
# Each group should have 2 people. You will be assigned a partner
#
# ## Parts:
# - Part 1: Complete 1 of 3 questions
# - Part 2: Review your partner's Assignment 1 submission
# - Part 3: Perform code review of your partner's assignment 1 by answering the questions below
# - Part 3: Reflect on Assignment 1 and Assignment 2
#
# ## Part 1:
#
# _*You will be assigned one of three problems based of your first name. Enter your first name, in all lower case, execute the code below, and that will tell you your assigned problem. Include the output as part of your submission (do not clear the output). The problems are based-off problems from Leetcode.*_

# %%
import hashlib

def hash_to_range(input_string: str) -> int:
     hash_object = hashlib.sha256(input_string.encode())
     hash_int = int(hash_object.hexdigest(), 16)
     return (hash_int % 3) + 1
input_string = "i made eka"
result = hash_to_range(input_string)
print(result)
# Out:
# 3

# %% [markdown]
# <details>
#   <summary>Question 1</summary>
#
#   # Question One: Check Duplicates in Tree
#
#   Given the `root` of a binary tree, check whether it is contains a duplicate value. If a duplicate exists, return the duplicate value. If there are multiple duplicates, return the one with the closest distance to the root. If no duplicate exists, return -1.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?*
#
#   Output: 2
#
#   ### Example 2
#
#   ![](./images/q1_ex2.png)
#
#   Input: `root = [1, 10, 2, 3, 10, 12, 12]`
#
#   Output: 10
#
#   ### Example 3
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 8, 7]`
#
#   Output: -1
#
# </details>
#
# #### Starter Code for Question 1

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val = 0, left = None, right = None):
#         self.val = val
#         self.left = left
#         self.right = right
def is_duplicate(root: TreeNode) -> int:
  # TODO

# %% [markdown]
# <details>
#   <summary>Question 2</summary>
#
#   # Question Two: Path to Leaves
#
#   Given the `root` of a binary tree, return all root to leaf paths in any order.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?*
#
#   Output: [[1, 2, 3], [1, 2, 5], [1, 2, 6], [1, 2, 7]]
#
#   ### Example 2
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 7, 8]`
#
#   Output: [[10, 7], [10, 9, 8]]
#
# </details>
#
# #### Starter Code for Question 2

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val = 0, left = None, right = None):
#         self.val = val
#         self.left = left
#         self.right = right
def bt_path(root: TreeNode) -> List[List[int]]:
  # TODO

# %% [markdown]
# <details>
#   <summary>Question 3</summary>
#
#   # Question Three: Missing Number in Range
#
#   You are given a list containing `n` integers in the range `[0, n]`. Return a list of numbers that are missing from the range `[0, n]` of the array. If there is no missing number, return -1. Note, all the integers in the list may not be unique.
#
#   ## Examples
#
#   ### Example 1
#
#   Input: `lst = [0, 2]`
#
#   Output: [1]
#
#   ### Example 2
#
#   Input: `lst = [5, 0, 1]`
#
#   Output: [2, 3, 4]
#
#   ### Example 3
#
#   Input: `lst = [6, 8, 2, 3, 5, 7, 0, 1, 10]`
#
#   Output: [4, 9]
#
# </details>
#
# #### Starter Code for Question 3

# %% [markdown]
# # Question Three: Missing Number in Range
#
#   You are given a list containing `n` integers in the range `[0, n]`. Return a list of numbers that are missing from the range `[0, n]` of the array. If there is no missing number, return -1. Note, all the integers in the list may not be unique.
#
#   ## Examples
#
#   ### Example 1
#
#   Input: `lst = [0, 2]`
#
#   Output: [1]
#
#   ### Example 2
#
#   Input: `lst = [5, 0, 1]`
#
#   Output: [2, 3, 4]
#
#   ### Example 3
#
#   Input: `lst = [6, 8, 2, 3, 5, 7, 0, 1, 10]`
#
#   Output: [4, 9]

# %%
# This is for n is non negative
from typing import List, Union

def missing_num(nums: List[int]) -> Union[List[int], int]:
    max_value = max(nums) # Find the max value of the list members
    full_range = set(range(0, max_value + 1)) # Create a new list that range [0,max_value]
    missing = sorted(list(full_range - set(nums))) # Remove the full_range list that contains nums list values

    if len(missing) == 0: # Check the length of missing list
        return -1 # If there is no missing number, return -1
    return missing # If the length of missing list != 0, then return the missing list


nums_1 = [0, 2]
print(missing_num(nums_1))

nums_2 = [5, 0, 1]
print(missing_num(nums_2))

nums_3 = [6, 8, 2, 3, 5, 7, 0, 1, 10]
print(missing_num(nums_3))

nums_4 = [0,1,2,2,5] # it can handle the not unique list values.
print(missing_num(nums_4))

nums_5 = [0]
print(missing_num(nums_5))

nums_6 = [0,-5] # Use the next function where list in the range of  [max_value and min_value]
print(missing_num(nums_6))
# Out:
# [1]
# [2, 3, 4]
# [4, 9]
# [3, 4]
# -1
# -1

# %%
# This is for the list in range of [min_value, max_value]
from typing import List, Union

def missing_num(nums: List[int]) -> Union[List[int], int]:
    max_value = max(nums) # Find the max value of the list members
    min_value = min(nums)
    full_range = set(range(min_value, max_value + 1)) # Create a new list that range [0,max_value]
    missing = sorted(list(full_range - set(nums))) # Remove the full_range list that contains nums list values

    if len(missing) == 0: # Check the length of missing list
        return -1 # If there is no missing number, return -1
    return missing # If the length of missing list != 0, then return the missing list

nums_6 = [0,-5] 
print(missing_num(nums_6))

nums_7 = [4,4,10,10,-5,-5] 
print(missing_num(nums_7))
# Out:
# [-4, -3, -2, -1]
# [-4, -3, -2, -1, 0, 1, 2, 3, 5, 6, 7, 8, 9]

# %% [markdown]
# ## Part 2:
#
# You and your partner must share each other's Assignment 1 submission.
#
# My parter is Chun-Yuan Chen. Here is the link of his A1:  https://github.com/Chun-YuanChen/algorithms_and_data_structures/pulls.

# %% [markdown]
# ## Part 3:
#
# Create a Jupyter Notebook, create 6 of the following headings, and complete the following for your partner's assignment 1:
#
# -   Paraphrase the problem in your own words.

# %% [markdown]
# # Your answer here
# There will be a string that contains only "(", ")", "{", "}", "]" and "[". The valid bracket sequence must follow:
# 1. If there is open bracket, then it must be closed with the same type of bracket. Example "(" will be closed with ")".
# 2. The order of closing must correct. Example "[()]" is correct, but "([)]" is not in order.

# %% [markdown]
# -   Create 1 new example that demonstrates you understand the problem. Trace/walkthrough 1 example that your partner made and explain it.

# %% [markdown]
# # Your answer here
# My parter created a function where input is a list and the output is a boolean. At first he created an empty list to collect the value of the input list. Besides that there is a dictionary to couple the key and value of the couple of brackets. Then it checked the element in the input list. Then it checked the elements whether it is contained in the keys or values of the dictionary. If the element is contained in the keys, then it will be appended into the empty list. If it is not contained in the keys, then the function will check whether the element can be contained in the values. Then check if this element couple can be found in the empty list. If yes, then pop the couple, otherwise return False. Do all the same flow for every elements. At the end if the empty string is empty, it means all the element has couple in order. It will return True. Meanwhile, if the length of empty string is not 0, then there is/are elements that has no couple. Then the return must be False.

# %% [markdown]
# -   Copy the solution your partner wrote.

# %%
# Your answer here
def is_valid_brackets(s: str) -> bool:
    empty_list = []
    defined_brackets = {"(": ")", "[": "]", "{": "}"}

    for element in s:
        if element in defined_brackets.keys(): # Reference: https://developers.google.com/edu/python/dict-files
            empty_list.append(element)

        elif element in defined_brackets.values(): # Reference: https://developers.google.com/edu/python/dict-files
            if not empty_list:
                return False
            last_opening_bracket = empty_list.pop(-1) # Reference: https://www.programiz.com/python-programming/methods/list/pop
            if defined_brackets[last_opening_bracket] != element:
                return False

        else:
            return False

    print(f"Check spot for empty_list: {empty_list}") # CYC: Add a check for empty_list: if it's True, the output should be []; otherwise, the output should be something other than an empty list. 
    return empty_list == []

# %% [markdown]
# -   Explain why their solution works in your own words.

# %% [markdown]
# # Your answer here
# At first dictionary that contains key and value as couples is created. Then The key of dictionary will be matched with the value that appear in the list. If the key and value match, then they will be ignored. At the end there will be a list that either empty because all of the velues are matched or there are values of the list that has no match. The first case will return True and the further case will return False.

# %% [markdown]
# -   Explain the problem’s time and space complexity in your own words.

# %% [markdown]
# # Your answer here
# Nothing is complicated in here. The time and space complexity is O(n).

# %% [markdown]
# -   Critique your partner's solution, including explanation, and if there is anything that should be adjusted.

# %% [markdown]
# # Your answer here
# I think there is no critique because the code already efficient with time and space complexity is O(n). It is interesting to reverse the key and value on dictionary by writting {")":"(","}":"{","]":"["}. It actually stated by my parter on his answer on relative solution.

# %% [markdown]
# ## Part 4:
#
# Please write a 200 word reflection documenting your process from assignment 1, and your presentation and review experience with your partner at the bottom of the Jupyter Notebook under a new heading "Reflection." Again, export this Notebook as pdf.

# %% [markdown]
# ### Reflection

# %% [markdown]
# # Your answer
# I found that the instruction of the Assignment 1 was not clear to connect the result of inputing our first name to the latter instruction. I got the problem 3 which moves all the zeros to the back of the list. Actually the problem can be solved with many solutions. I choose to create a list contains all zeros values, then substitute the first N value with non zero from the input list. My alternative solution by counting the number of zeros in the input list, then move the non zero input list forward then create the 0 values which length is equal with length of input list - N.
#
# Review of my parter code is straightforward since his code is clear and efficient. There is a little impovement I can suggest, but his alternative solution is interesting to try. The efficiancy will be the same but I prefer the logic in the reverse order of the dictionary.

# %% [markdown]
# ## Evaluation Criteria
#
# We are looking for the similar points as Assignment 1
#
# -   Problem is accurately stated
#
# -   New example is correct and easily understandable
#
# -   Correctness, time, and space complexity of the coding solution
#
# -   Clarity in explaining why the solution works, its time and space complexity
#
# -   Quality of critique of your partner's assignment, if necessary

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-2`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_2.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/algorithms_and_data_structures/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-6-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
